# %%
import numpy as np
import scanpy as sc
import cell2location
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import rcParams

# %%
rcParams['pdf.fonttype'] = 42 # 设置图表字体为TrueType，确保在保存为PDF时字体清晰可编辑

adata_vis = sc.datasets.visium_sge(sample_id="V1_Human_Lymph_Node") # 下载空间转录组数据，包含一个人类淋巴结的切片数据，是anndata对象

adata_ref = sc.read(
    f'./data/sc.h5ad',
    backup_url='https://cell2location.cog.sanger.ac.uk/paper/integrated_lymphoid_organ_scrna/RegressionNBV4Torch_57covariates_73260cells_10237genes/sc.h5ad')
# 用于加载包含单细胞 RNA 测序（scRNA-seq）参考数据的文件
# Out:
# C:\Users\Emily\AppData\Local\Temp\ipykernel_7608\3821485017.py:3: FutureWarning: Use `squidpy.datasets.visium` instead.
#   adata_vis = sc.datasets.visium_sge(sample_id="V1_Human_Lymph_Node") # 下载空间转录组数据，包含一个人类淋巴结的切片数据，是anndata对象
# 100%|██████████| 7.86M/7.86M [00:01<00:00, 4.42MB/s]
# 100%|██████████| 29.3M/29.3M [00:06<00:00, 4.85MB/s]
# D:\Install\Python\Lib\site-packages\anndata\_core\anndata.py:1825: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
#  87%|████████▋ | 457M/527M [02:35<00:23, 3.07MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       1 rcParams['pdf.fonttype'] = 42 # 设置图表字体为TrueType，确保在保存为PDF时字体清晰可编辑
#       2
#       3 adata_vis = sc.datasets.visium_sge(sample_id="V1_Human_Lymph_Node") # 下载空间转录组数据，包含一个人类淋巴结的切片数据，是anndata对象
#       4
# ...
